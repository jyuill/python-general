# %% [markdown]
# # Pandas Tutorial from YT video
#
# Rob Mulla: https://www.youtube.com/watch?v=DkjCaAMBGWM

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## I/O Reading & Writing
#
# Getting data.
#
# Tutorial has a link to download flights data from Kaggle repo. Was not able to successfully download - was in zip file and looks VERY large.
#
# Will follow along with my own data.

# %%
df_exp = pd.read_csv('exp_cats_gpt.csv')

# %% [markdown]
# ## Explore

# %%
# get random sample of rows
df_exp.sample(10)
# Out:
#       type                  date  amount                             id  \
# 241  DEBIT  2025-02-24T00:00:00Z  -40.82                  2025022443125
# 471  DEBIT  2025-03-19T00:00:00Z   -0.04  2025-02-20~2025-03-19~2058228
# 397  DEBIT  2025-05-02T00:00:00Z   -5.00              25122182730391000
# 0    DEBIT  2025-03-02T00:00:00Z  -12.65         809-45080-100003027281
# 351  DEBIT  2025-06-30T00:00:00Z  -84.34                            NaN
# 506  DEBIT  2025-05-06T00:00:00Z   -5.00  2025-04-22~2025-05-07~1754092
# 607  DEBIT  2025-07-28T00:00:00Z  -10.49                202507281032279
# 626  DEBIT  2025-07-19T00:00:00Z -810.16              1000030272813281D
# 272  DEBIT  2025-04-01T00:00:00Z  -14.69                202504011354532
# 382  DEBIT  2025-03-31T00:00:00Z   -3.95              25091051245920030
#
#                           name                                           memo  \
# 241     DD/DOORDASHIGNITEPIZZE                         DD/DOORDASHIGNITEPIZZE
# 471  INTEREST CHARGE -PURCHASE                                            NaN
# 397               NSF PAID FEE                                            NaN
# 0     Point Of Sale Withdrawal                            Store VancouverBCCA
# 351                   DoorDash                                         Dining
# 506            IMPARK00011928U                                            NaN
# 607           DOORDASHDASHPASS                               DOORDASHDASHPASS
# 626               Bill Payment  Capital One Mastercard, Confirmation 59406182
# 272               GITHUB, INC.                                   GITHUB, INC.
# 382        MONTHLY ACCOUNT FEE                                            NaN
#
#            source          category           spend_type vendor    month  \
# 241  cap_one_visa        food & bev  nec - discretionary    NaN  02-2025
# 471       td_visa  int/bank chg/tax        discretionary    NaN  03-2025
# 397         td_ch  int/bank chg/tax          nec - fixed    NaN  05-2025
# 0         beem_ch        food & bev  nec - discretionary    NaN  03-2025
# 351  cap_one_visa        food & bev  nec - discretionary    NaN  06-2025
# 506       td_visa  auto/local trans        discretionary    NaN  05-2025
# 607  cap_one_visa        food & bev                  NaN    NaN  07-2025
# 626       beem_ch      transfer/pmt                  NaN    NaN  07-2025
# 272  cap_one_visa          business          bus - fixed    NaN  04-2025
# 382         td_ch  int/bank chg/tax          nec - fixed    NaN  03-2025
#
#      year                 added  updated
# 241  2025                   NaN      NaN
# 471  2025                   NaN      NaN
# 397  2025                   NaN      NaN
# 0    2025                   NaN      NaN
# 351  2025                   NaN      NaN
# 506  2025                   NaN      NaN
# 607  2025  2025-08-01T00:00:00Z      NaN
# 626  2025  2025-08-01T00:00:00Z      NaN
# 272  2025                   NaN      NaN
# 382  2025                   NaN      NaN

# %%
# get random sample of fraction of rows
df_exp.sample(frac=0.1) # 10% of rows
# Out:
#        type                  date   amount                             id  \
# 319   DEBIT  2025-05-26T00:00:00Z  -112.45                202505261004078
# 402   DEBIT  2025-05-12T00:00:00Z  -617.96              25131234704091000
# 48    DEBIT  2025-04-01T00:00:00Z  -845.38                           3093
# 51    DEBIT  2025-04-02T00:00:00Z  -132.83                           3096
# 297   DEBIT  2025-04-28T00:00:00Z   -32.54                202504281037598
# ..      ...                   ...      ...                            ...
# 225  CREDIT  2025-07-15T00:00:00Z  1503.30              1000030272813272C
# 296   DEBIT  2025-04-28T00:00:00Z   -10.49                202504281037608
# 581   DEBIT  2025-07-14T00:00:00Z   -10.75  2025-06-20~2025-07-15~1803510
# 288   DEBIT  2025-04-19T00:00:00Z   -43.14                 20250419950388
# 201   DEBIT  2025-07-03T00:00:00Z  -185.06              1000030272813244D
#
#                              name                                       memo  \
# 319        DD/DOORDASHIGNITEPIZZE                     DD/DOORDASHIGNITEPIZZE
# 402               RODNEY'S OYSTER                                        NaN
# 48   External Withdrawal Mortgage              Home Trust Company 0002824971
# 51       Point Of Sale Withdrawal      INDIAN FUSION RESTAURA NORTH VANCBCCA
# 297                      REBEL.CA                                   REBEL.CA
# ..                            ...                                        ...
# 225              External Deposit  Rent/Leases VANTAGE WEST-NEW TRUST AR4070
# 296              DOORDASHDASHPASS                           DOORDASHDASHPASS
# 581                         TESLA                                        NaN
# 288        DD/DOORDASHJUKEFRIEDCH                     DD/DOORDASHJUKEFRIEDCH
# 201      Point Of Sale Withdrawal       GRANVILLE ISLAND KEG # VANCOUVERBCCA
#
#            source       category           spend_type vendor    month  year  \
# 319  cap_one_visa     food & bev  nec - discretionary    NaN  05-2025  2025
# 402         td_ch     food & bev  nec - discretionary    NaN  05-2025  2025
# 48        beem_ch     rental inc  nec - discretionary    NaN  04-2025  2025
# 51        beem_ch     food & bev                  NaN     EA  04-2025  2025
# 297  cap_one_visa       business          bus - fixed    NaN  04-2025  2025
# ..            ...            ...                  ...    ...      ...   ...
# 225       beem_ch     rental inc                  NaN    NaN  07-2025  2025
# 296  cap_one_visa     food & bev  nec - discretionary    NaN  04-2025  2025
# 581       td_visa  entertainment                  NaN    NaN  07-2025  2025
# 288  cap_one_visa     food & bev  nec - discretionary    NaN  04-2025  2025
# 201       beem_ch     food & bev                  NaN    NaN  07-2025  2025
#
#     added  updated
# 319   NaN      NaN
# 402   NaN      NaN
# 48    NaN      NaN
# 51    NaN      NaN
# 297   NaN      NaN
# ..    ...      ...
# 225   NaN      NaN
# 296   NaN      NaN
# 581   NaN      NaN
# 288   NaN      NaN
# 201   NaN      NaN
#
# [63 rows x 14 columns]

# %%
# random fraction, set seed
df_exp.sample(frac=0.1, random_state=111)
# Out:
#        type                  date   amount                      id  \
# 422   DEBIT  2025-06-02T00:00:00Z  -371.28       25153131828271000
# 150   DEBIT  2025-06-08T00:00:00Z    -9.99       1000030272813201D
# 261   DEBIT  2025-03-19T00:00:00Z   -39.04          20250319955089
# 192   DEBIT  2025-06-25T00:00:00Z   -84.24       1000030272813236D
# 12    DEBIT  2025-03-10T00:00:00Z    -2.82  809-45080-100003027281
# ..      ...                   ...      ...                     ...
# 237   DEBIT  2025-02-21T00:00:00Z  -128.51         202502211004570
# 251   DEBIT  2025-03-05T00:00:00Z    -3.13         202503051027057
# 249   DEBIT  2025-03-03T00:00:00Z   -15.67           2025030349566
# 39   CREDIT  2025-03-28T00:00:00Z  1800.00  809-45080-100003027281
# 421   DEBIT  2025-06-02T00:00:00Z  -634.85       25153131828231000
#
#                          name                                            memo  \
# 422       KOODO MOBILE J5Q3L4                                             NaN
# 150  Point Of Sale Withdrawal                            JAPADOG RICHMONDBCCA
# 261    DD/DOORDASHTHEPERIPERI                          DD/DOORDASHTHEPERIPERI
# 192  Point Of Sale Withdrawal                WHOLE FOODS MARKET VANCOUVERBCCA
# 12   Point Of Sale Withdrawal                  365 MARKET CA 2 MISSISSAUGONCA
# ..                        ...                                             ...
# 237            ATHLETICGREENS                                  ATHLETICGREENS
# 251        GOOGLE *Google One                              GOOGLE *Google One
# 249                     TESLA                                           TESLA
# 39           External Deposit  Payroll Deposit Electronic Arts Inc. 202503281
# 421       CAPTL ONE MC J5Q3L3                                             NaN
#
#            source       category           spend_type vendor    month  year  \
# 422         td_ch      utilities          nec - fixed    NaN  06-2025  2025
# 150       beem_ch     food & bev  nec - discretionary    NaN  06-2025  2025
# 261  cap_one_visa     food & bev  nec - discretionary    NaN  03-2025  2025
# 192       beem_ch     food & bev  nec - discretionary    NaN  06-2025  2025
# 12        beem_ch     food & bev  nec - discretionary    NaN  03-2025  2025
# ..            ...            ...                  ...    ...      ...   ...
# 237  cap_one_visa     food & bev  nec - discretionary    NaN  02-2025  2025
# 251  cap_one_visa      utilities          nec - fixed    NaN  03-2025  2025
# 249  cap_one_visa  entertainment        discretionary    NaN  03-2025  2025
# 39        beem_ch         income                  NaN    NaN  03-2025  2025
# 421         td_ch   transfer/pmt                  NaN    NaN  06-2025  2025
#
#     added  updated
# 422   NaN      NaN
# 150   NaN      NaN
# 261   NaN      NaN
# 192   NaN      NaN
# 12    NaN      NaN
# ..    ...      ...
# 237   NaN      NaN
# 251   NaN      NaN
# 249   NaN      NaN
# 39    NaN      NaN
# 421   NaN      NaN
#
# [63 rows x 14 columns]
